# %%
#1

# %%
def h(x): return -x^2 + 4*x

# %%
plot(h(x),(x,-3,6),legend_label='h(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(h(x),(x,2,6),legend_label='h(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(h(x),(x,-3,1),legend_label='h(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#43

# %%
def f(x): return (x^2 - 1)/(x + 1)

# %%
plot(f(x),(x,-3,1),legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#79

# %%
t= var('t')

# %%
def f(t): return sin(3*t)/t

# %%
plot(f(t),(t,-2,2),legend_label='f(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f(-2))
# Out:
# -0.139707749099463

# %%
n(f(-1))
# Out:
# 0.141120008059867

# %%
n(f(-0.5))
# Out:
# 1.99498997320811

# %%
n(f(-0.1))
# Out:
# 2.95520206661340

# %%
n(f(-0.01))
# Out:
# 2.99955002024957

# %%
n(f(0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 n(f(Integer(0)))
#
# Cell In [5], line 1, in f(t)
# ----> 1 def f(t): return sin(Integer(3)*t)/t
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
n(f(0.01))
# Out:
# 2.99955002024957

# %%
n(f(0.1))
# Out:
# 2.95520206661340

# %%
n(f(0.5))
# Out:
# 1.99498997320811

# %%
n(f(1))
# Out:
# 0.141120008059867

# %%
n(f(2))
# Out:
# -0.139707749099463

# %%
#93

# %%
def f2(x): return x*sin(1/x)

# %%
def h2(x): return abs(x)

# %%
def g2(x): return -abs(x)

# %%
p=[]

# %%
p.append(plot(f2(x),(x,-1,1),color='blue',legend_label='f2(x)'))

# %%
p.append(plot(h2(x),(x,-1,1),color='green',legend_label='h2(x)'))

# %%
p.append(plot(g2(x),(x,-1,1),color='red',legend_label='g2(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#99

# %%
def f3(x): return x

# %%
def g3(x): return sin(x)

# %%
def h3(x): return sin(x)/x

# %%
p=[]

# %%
p.append(plot(f3(x),(x,-1,1),color='blue',legend_label='f3(x)'))

# %%
p.append(plot(g3(x),(x,-1,1),color='red',legend_label='g3(x)'))

# %%
p.append(plot(h3(x),(x,-1,1),color='green',legend_label='h3(x)'))

# %%
sum(p)
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#123

# %%
def f4(x): return (sec(x) - 1)/x^2

# %%
plot(f4(x),(x,-6,6),ymin=-10,ymax=10,color='blue',legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f4(x),(x,-1,1),color='blue',legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f4(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 f4(Integer(0))
#
# Cell In [2], line 1, in f4(x)
# ----> 1 def f4(x): return (sec(x) - Integer(1))/x**Integer(2)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f4(-0.001)
# Out:
# 0.500000208347728

# %%
f4(0.001)
# Out:
# 0.500000208347728
