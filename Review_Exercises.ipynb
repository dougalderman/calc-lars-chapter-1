# %%
#3

# %%
def f(x): return (x-3)/(x^2-7*x+12)

# %%
plot(f(x),(x,0,6),ymin=-10,ymax=10,legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(2.9)
# Out:
# -0.909090909090915

# %%
f(2.99)
# Out:
# -0.990099009900839

# %%
f(2.999)
# Out:
# -0.999000999002189

# %%
f(3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 f(Integer(3))
#
# Cell In [2], line 1, in f(x)
# ----> 1 def f(x): return (x-Integer(3))/(x**Integer(2)-Integer(7)*x+Integer(12))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f(3.001)
# Out:
# -1.00100100100248

# %%
f(3.01)
# Out:
# -1.01010101010081

# %%
f(3.1)
# Out:
# -1.11111111111114

# %%
#33

# %%
def f2(x): return (sqrt(2*x + 9) - 3)/x

# %%
plot(f2(x),(x,-3,3),legend_label='f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f2(-1))
# Out:
# 0.354248688935409

# %%
n(f2(-0.5))
# Out:
# 0.343145750507619

# %%
n(f2(-0.1))
# Out:
# 0.335206051617347

# %%
n(f2(-0.01))
# Out:
# 0.333518724566062

# %%
n(f2(-0.001))
# Out:
# 0.333351853909925

# %%
n(f2(0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 n(f2(Integer(0)))
#
# Cell In [2], line 1, in f2(x)
# ----> 1 def f2(x): return (sqrt(Integer(2)*x + Integer(9)) - Integer(3))/x
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
n(f2(0.001))
# Out:
# 0.333314816872043

# %%
n(f2(0.01))
# Out:
# 0.333148353624102

# %%
n(f2(0.1))
# Out:
# 0.331501776206200

# %%
n(f2(0.5))
# Out:
# 0.324555320336759

# %%
n(f2(1))
# Out:
# 0.316624790355400

# %%
#35

# %%
def f3(x): return (x^3 + 125)/(x + 5)

# %%
plot(f3(x),(x,-6,-4),legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f3(-6))
# Out:
# 91.0000000000000

# %%
n(f3(-5.5))
# Out:
# 82.7500000000000

# %%
n(f3(-5.1))
# Out:
# 76.5100000000001

# %%
n(f3(-5.01))
# Out:
# 75.1501000000006

# %%
n(f3(-5.001))
# Out:
# 75.0150010000004

# %%
n(f3(-5))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [26], line 1
# ----> 1 n(f3(-Integer(5)))
#
# Cell In [17], line 1, in f3(x)
# ----> 1 def f3(x): return (x**Integer(3) + Integer(125))/(x + Integer(5))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
n(f3(-4.999))
# Out:
# 74.9850010000051

# %%
n(f3(-4.99))
# Out:
# 74.8501000000006

# %%
n(f3(-4.9))
# Out:
# 73.5100000000000

# %%
n(f3(-4.5))
# Out:
# 67.7500000000000

# %%
n(f3(-4))
# Out:
# 61.0000000000000

# %%
#53

# %%
def f4(x): return x/(x^3 -x)

# %%
plot(f4(x),(x,-2,2),ymin=-10,ymax=10,legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive
