# %%
#11

# %%
def f(x): return x^2/(x^2 - 9)

# %%
plot(f(x),(x,-6,0),ymin=-20,ymax=20,legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(-3.5)
# Out:
# 3.76923076923077

# %%
f(-3.1)
# Out:
# 15.7540983606557

# %%
f(-3.01)
# Out:
# 150.750415973381

# %%
f(-3.001)
# Out:
# 1500.75004165985

# %%
f(-3)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 f(-Integer(3))
#
# Cell In [2], line 1, in f(x)
# ----> 1 def f(x): return x**Integer(2)/(x**Integer(2) - Integer(9))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f(-2.999)
# Out:
# -1499.25004167381

# %%
f(-2.99)
# Out:
# -149.250417362273

# %%
f(-2.9)
# Out:
# -14.2542372881356

# %%
f(-2.5)
# Out:
# -2.27272727272727

# %%
#29

# %%
def f1(x): return (x^2 - 1)/(x + 1)

# %%
plot(f1(x),(x,-4,2),legend_label='f1(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f1(-0.9)
# Out:
# -1.90000000000000

# %%
f1(-1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 f1(-Integer(1))
#
# Cell In [2], line 1, in f1(x)
# ----> 1 def f1(x): return (x**Integer(2) - Integer(1))/(x + Integer(1))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f1(-1.1)
# Out:
# -2.10000000000000

# %%
#51

# %%
def f2(x): return 1/(x^2 - 25)

# %%
plot(f2(x),(x,4,6),ymin=-10,ymax=10,legend_label='f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f2(x),(x,-6,-4),ymin=-10,ymax=10,legend_label='f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#59a

# %%
def f3(x): return (x-sin(x))/x

# %%
plot(f3(x),(x,-2,2),legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f3(1))
# Out:
# 0.158529015192103

# %%
n(f3(0.5))
# Out:
# 0.0411489227915940

# %%
n(f3(0.2))
# Out:
# 0.00665334602469397

# %%
n(f3(0.1))
# Out:
# 0.00166583353171851

# %%
n(f3(0.01))
# Out:
# 0.0000166665833335744

# %%
n(f3(0.001))
# Out:
# 1.66666658339004e-7

# %%
n(f3(0.0001))
# Out:
# 1.66666661483190e-9

# %%
#59b

# %%
def f4(x): return (x-sin(x))/x^2

# %%
plot(f4(x),(x,-2,2),legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f4(1))
# Out:
# 0.158529015192103

# %%
n(f4(0.5))
# Out:
# 0.0822978455831880

# %%
n(f4(0.2))
# Out:
# 0.0332667301234699

# %%
n(f4(0.1))
# Out:
# 0.0166583353171851

# %%
n(f4(0.01))
# Out:
# 0.00166665833335744

# %%
n(f4(0.001))
# Out:
# 0.000166666658339004

# %%
n(f4(0.0001))
# Out:
# 0.0000166666661483190

# %%
#59c

# %%
def f5(x): return (x-sin(x))/x^3

# %%
plot(f5(x),(x,-2,2),legend_label='f5(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f5(1))
# Out:
# 0.158529015192103

# %%
n(f5(0.5))
# Out:
# 0.164595691166376

# %%
n(f5(0.2))
# Out:
# 0.166333650617349

# %%
n(f5(0.1))
# Out:
# 0.166583353171851

# %%
n(f5(0.01))
# Out:
# 0.166665833335744

# %%
n(f5(0.001))
# Out:
# 0.166666658339004

# %%
n(f5(0.0001))
# Out:
# 0.166666661483190

# %%
f5(0.0001)
# Out:
# 0.166666661483190

# %%
#59d

# %%
def f6(x): return (x-sin(x))/x^4

# %%
plot(f6(x),(x,-2,2),ymin=-10,ymax=10,legend_label='f6(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f6(1))
# Out:
# 0.158529015192103

# %%
n(f6(0.5))
# Out:
# 0.329191382332752

# %%
n(f6(0.2))
# Out:
# 0.831668253086747

# %%
n(f6(0.1))
# Out:
# 1.66583353171851

# %%
n(f6(0.01))
# Out:
# 16.6665833335744

# %%
n(f6(0.001))
# Out:
# 166.666658339004

# %%
n(f6(0.0001))
# Out:
# 1666.66661483190

# %%
#63

# %%
def f7(x): return 50*(tan(x) - x)

# %%
plot(f7(x),(x,0,1.5),ymin=-20,ymax=20,legend_label='f7(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n(f7(0.3))
# Out:
# 0.466812480481163

# %%
n(f7(0.6))
# Out:
# 4.20684041708462

# %%
n(f7(0.9))
# Out:
# 18.0079108775170

# %%
n(f7(1.2))
# Out:
# 68.6075811063159

# %%
n(f7(1.5))
# Out:
# 630.070997358586
