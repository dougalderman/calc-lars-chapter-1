# %%
#117

# %%
x<-c(0,5,10,15,20,25,30)
y<-c(0,48.2,53.5,55.2,55.9,56.2,56.3)

# %%
plot(x,y,col="blue", main="Speed of Falling Object vs. Time",xlab="Time (seconds)", ylab="Speed (Feet/Second)")
# Out:
# Plot with title “Speed of Falling Object vs. Time”

# %%
relation_nl<-nls(y~a*log(b*x),start=list(a=1,b=1))
print(relation_nl)
summary(relation_nl)
# Out:
# Error in numericDeriv(form[[3L]], names(ind), env, central = nDcentral): Missing value or an infinity produced when evaluating the model
# Traceback:
#
# 1. nls(y ~ a * log(b * x), start = list(a = 1, b = 1))
# 2. nlsModel(formula, mf, start, wts, scaleOffset = scOff, nDcentral = nDcntr)
# 3. getRHS()
# 4. numericDeriv(form[[3L]], names(ind), env, central = nDcentral)
