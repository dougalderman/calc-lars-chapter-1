# %%
#1

# %%
def f(x): return (x-4)/(x^2 - 3*x -4)

# %%
plot(f(x),(x,1,7),legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(3.9)
# Out:
# 0.204081632653061

# %%
f(3.99)
# Out:
# 0.200400801603205

# %%
f(3.999)
# Out:
# 0.200040008001588

# %%
f(4)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [35], line 1
# ----> 1 f(Integer(4))
#
# Cell In [30], line 1, in f(x)
# ----> 1 def f(x): return (x-Integer(4))/(x**Integer(2) - Integer(3)*x -Integer(4))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f(4.001)
# Out:
# 0.199960007998324

# %%
f(4.01)
# Out:
# 0.199600798403195

# %%
f(4.1)
# Out:
# 0.196078431372548

# %%
#7

# %%
def f2(x): return (x-2)/(x^2+x-6)

# %%
plot(f2(x),(x,-2,4),legend_label='f2(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f2(0.9)
# Out:
# 0.256410256410256

# %%
f2(0.99)
# Out:
# 0.250626566416040

# %%
f2(0.999)
# Out:
# 0.250062515628907

# %%
f2(1)
# Out:
# 1/4

# %%
f2(1.001)
# Out:
# 0.249937515621095

# %%
f2(1.01)
# Out:
# 0.249376558603491

# %%
f2(1.1)
# Out:
# 0.243902439024390

# %%
#13

# %%
def f3(x): return sin(2*x)/x

# %%
plot(f3(x),(x,-3,3),legend_label='f3(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f3(-0.1)
# Out:
# 1.98669330795061

# %%
f3(-0.01)
# Out:
# 1.99986666933331

# %%
f3(-0.001)
# Out:
# 1.99999866666693

# %%
f3(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [56], line 1
# ----> 1 f3(Integer(0))
#
# Cell In [51], line 1, in f3(x)
# ----> 1 def f3(x): return sin(Integer(2)*x)/x
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f3(0.001)
# Out:
# 1.99999866666693

# %%
f3(0.01)
# Out:
# 1.99986666933331

# %%
f3(0.1)
# Out:
# 1.98669330795061

# %%
#53

# %%
def f4(x): return (x-9)/(sqrt(x) - 3)

# %%
plot(f4(x),(x,6,12),legend_label='f4(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(8.9)
# Out:
# 5.98328677803520

# %%
f(9)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 f(Integer(9))
#
# Cell In [2], line 1, in f(x)
# ----> 1 def f(x): return (x-Integer(9))/(sqrt(x) - Integer(3))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f(9.1)
# Out:
# 6.01662062579963

# %%
plot(f4(x),(x,-12,12),legend_label='f4(x)')
# Out:
# verbose 0 (3935: plot.py, generate_plot_points) WARNING: When plotting, failed to evaluate function at 100 points.
# verbose 0 (3935: plot.py, generate_plot_points) Last error message: 'Unable to compute f(-0.01295647293091104)'
# Graphics object consisting of 1 graphics primitive

# %%
#55

# %%
t = var('t')

# %%
def C(t): return 9.99 - 0.79*floor(-(t-1))

# %%
plot(C(t),(t,0,6),legend_label='C(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
C(3)
# Out:
# 11.5700000000000

# %%
C(3.3)
# Out:
# 12.3600000000000

# %%
C(3.4)
# Out:
# 12.3600000000000

# %%
C(3.5)
# Out:
# 12.3600000000000

# %%
C(3.6)
# Out:
# 12.3600000000000

# %%
C(3.7)
# Out:
# 12.3600000000000

# %%
C(4)
# Out:
# 12.3600000000000

# %%
C(2)
# Out:
# 10.7800000000000

# %%
C(2.5)
# Out:
# 11.5700000000000

# %%
C(2.9)
# Out:
# 11.5700000000000

# %%
C(3)
# Out:
# 11.5700000000000

# %%
C(3.1)
# Out:
# 12.3600000000000

# %%
C(3.5)
# Out:
# 12.3600000000000

# %%
C(4)
# Out:
# 12.3600000000000

# %%
#63

# %%
def f5(x): return (1 + x)^(1/x)

# %%
plot(f5(x),(x,-.7,1),legend_label='f5(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f5(-1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 f5(-Integer(1))
#
# Cell In [2], line 1, in f5(x)
# ----> 1 def f5(x): return (Integer(1) + x)**(Integer(1)/x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2186, in sage.rings.integer.Integer.__pow__()
#    2184     return (<Integer>left)._pow_(right)
#    2185 elif isinstance(left, Element):
# -> 2186     return coercion_model.bin_op(left, right, operator.pow)
#    2187 # left is a non-Element: do the powering with a Python int
#    2188 return left ** int(right)
#
# File /ext/sage/10.1/src/sage/structure/coerce.pyx:1225, in sage.structure.coerce.CoercionModel.bin_op()
#    1223     self._record_exception()
#    1224 else:
# -> 1225     return PyObject_CallObject(op, xy)
#    1226
#    1227 if op is mul:
#
# ...

# %%
f5(-0.5)

# %%
f5(-0.1)
# Out:
# 2.86797199079244

# %%
f5(-0.01)
# Out:
# 2.73199902642903

# %%
f5(-0.001)
# Out:
# 2.71964221644285

# %%
f5(-0.0001)
# Out:
# 2.71841775501015

# %%
f5(-0.00001)
# Out:
# 2.71829541998041

# %%
f5(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 f5(Integer(0))
#
# Cell In [2], line 1, in f5(x)
# ----> 1 def f5(x): return (Integer(1) + x)**(Integer(1)/x)
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f5(0.00001)
# Out:
# 2.71826823719230

# %%
f5(0.0001)
# Out:
# 2.71814592682493

# %%
f5(0.001)
# Out:
# 2.71692393223559

# %%
f5(0.01)
# Out:
# 2.70481382942153

# %%
f5(0.1)
# Out:
# 2.59374246010000

# %%
f5(0.5)
# Out:
# 2.25000000000000

# %%
f5(1)
# Out:
# 2

# %%
#65

# %%
def f6(x): return abs((x^2 -4)/(x-2) - 4)

# %%
p=[]

# %%
p.append(plot(f6(x),(x,-1,4),color='blue',legend_label='f6(x)'))

# %%
p.append(plot(0.001,(x,-1,4),color='red',legend_label='y = 0.001'))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
q=[]

# %%
q.append(plot(f6(x),(x,1.9,2.1),color='blue',legend_label='f6(x)'))

# %%
q.append(plot(0.001,(x,1.9,2.1),color='red',legend_label='y = 0.001'))

# %%
sum(q)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
r=[]

# %%
r.append(plot(f6(x),(x,1.99,2.01),color='blue',legend_label='f6(x)'))

# %%
r.append(plot(0.001,(x,1.99,2.01),color='red',legend_label='y = 0.001'))

# %%
sum(r)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
s=[]

# %%
s.append(plot(f6(x),(x,1.999,2.001),color='blue',legend_label='f6(x)'))

# %%
s.append(plot(0.001,(x,1.999,2.001),color='red',legend_label='y = 0.001'))

# %%
sum(s)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f6(2)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 f6(Integer(2))
#
# Cell In [2], line 1, in f6(x)
# ----> 1 def f6(x): return abs((x**Integer(2) -Integer(4))/(x-Integer(2)) - Integer(4))
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f6(1.9995)
# Out:
# 0.000499999999625800

# %%
f6(2.0005)
# Out:
# 0.000500000000513978

# %%
#73

# %%
def f7(x): return sin(x)/x

# %%
plot(f7(x),(x,-2,2),color='blue',legend_label='f7(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f7(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 f7(Integer(0))
#
# Cell In [2], line 1, in f7(x)
# ----> 1 def f7(x): return sin(x)/x
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f7(-0.01)
# Out:
# 0.999983333416666

# %%
f7(0.01)
# Out:
# 0.999983333416666

# %%
def f8(x): return sin(2*x)/x

# %%
plot(f8(x),(x,-2,2),color='blue',legend_label='f8(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f8(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 f8(Integer(0))
#
# Cell In [7], line 1, in f8(x)
# ----> 1 def f8(x): return sin(Integer(2)*x)/x
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f8(-0.01)
# Out:
# 1.99986666933331

# %%
f8(0.01)
# Out:
# 1.99986666933331

# %%
def f9(x): return sin(3*x)/x

# %%
plot(f9(x),(x,-2,2),color='blue',legend_label='f9(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f9(0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 f9(Integer(0))
#
# Cell In [12], line 1, in f9(x)
# ----> 1 def f9(x): return sin(Integer(3)*x)/x
#
# File /ext/sage/10.1/src/sage/rings/integer.pyx:2015, in sage.rings.integer.Integer.__truediv__()
#    2013 if type(left) is type(right):
#    2014     if mpz_sgn((<Integer>right).value) == 0:
# -> 2015         raise ZeroDivisionError("rational division by zero")
#    2016     x = <Rational> Rational.__new__(Rational)
#    2017     mpq_div_zz(x.value, (<Integer>left).value, (<Integer>right).value)
#
# ZeroDivisionError: rational division by zero

# %%
f9(-0.01)
# Out:
# 2.99955002024957

# %%
f9(0.01)
# Out:
# 2.99955002024957
