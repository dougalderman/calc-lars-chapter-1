# %%
#75

# %%
def g1(x): return x^2 - 3*x

# %%
def g2(x): return 2*x - 5

# %%
p=[]

# %%
p.append(plot(g1(x),(x,4,7),legend_label='g(x)'))

# %%
p.append(plot(g2(x),(x,1,4)))

# %%
sum(p)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
g1(4)
# Out:
# 4

# %%
g2(4)
# Out:
# 3

# %%
#85

# %%
def f(x): return sin(x)/x

# %%
plot(f(x),(x,-4,4),legend_label='f(x)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
#93

# %%
t = var('t')

# %%
def g(t): return 2*cos(t) - 3*t

# %%
plot(g(t),(t,0,1),legend_label='g(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(g(t),(t,0.4,0.6),legend_label='g(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(g(t),(t,0.55,0.60),legend_label='g(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(g(t),(t,0.56,0.57),legend_label='g(t)')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
g(t).roots()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In [14], line 1
# ----> 1 g(t).roots()
#
# File /ext/sage/10.1/src/sage/symbolic/expression.pyx:12334, in sage.symbolic.expression.Expression.roots()
#   12332 S, mul = self.solve(x, multiplicities=True, explicit_solutions=explicit_solutions)
#   12333 if len(mul) == 0 and explicit_solutions:
# > 12334     raise RuntimeError("no explicit roots found")
#   12335 else:
#   12336     rt_muls = [(S[i].rhs(), mul[i]) for i in range(len(mul))]
#
# RuntimeError: no explicit roots found

# %%
find_root(g(t), 0.56, 0.57)
# Out:
# 0.5635692042255156
